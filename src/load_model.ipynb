# %%
from lib.models.model import create_model

# %%
net=create_model('cspfpnmulti18','','',pretrained='/home/myx/project/face_detection/models/58_0.64-13_00.pth')
# Out:
# {'mulit_stage': True, 'change_s1': True, 'layer_conf': {'layer0': {'conv': {'k': 4, 'p': 1, 'd': 1, 's': 2}, 'down': {'k': 2, 'p': 0, 'd': 1, 's': 2}}, 'layer1': {'conv': {'k': 4, 'p': 1, 'd': 1, 's': 2}, 'down': {'k': 2, 'p': 0, 'd': 1, 's': 2}}, 'layer2': {'conv': {'k': 4, 'p': 1, 'd': 1, 's': 2}, 'down': {'k': 2, 'p': 0, 'd': 1, 's': 2}}, 'layer3': {'conv': {'k': 4, 'p': 1, 'd': 1, 's': 2}, 'down': {'k': 2, 'p': 0, 'd': 1, 's': 2}}, 'layer4': {'conv': {'k': 4, 'p': 3, 'd': 2, 's': 1}, 'down': {'k': 1, 'p': 0, 'd': 1, 's': 1}}}}
# /home/myx/project/face_detection/models/58_0.64-13_00.pth
# s
# begin load
# layer4.0.downsample.0.weight
# linear.weight
# linear.bias
# miss params
# layeri0.0.weight True
# layeri0.1.weight True
# layeri0.1.bias True
# layeri1.0.conv1.weight True
# layeri1.0.bn1.weight True
# layeri1.0.bn1.bias True
# layeri1.0.conv2.weight True
# layeri1.0.bn2.weight True
# layeri1.0.bn2.bias True
# layer0.0.conv1.weight True
# layer0.0.bn1.weight True
# ...
