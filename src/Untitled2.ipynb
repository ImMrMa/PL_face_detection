# %%
import _init_paths
from datasets.dataset_factory import get_dataset
# %matplotlib inline
from matplotlib import pyplot as plt

import torch
import torch.utils.data

# %%
data=get_dataset('wider_csp','fadet')

# %%
val_loader = torch.utils.data.DataLoader(
        data(mode='val'),
        batch_size=10,
        shuffle=True,
        num_workers=1,
        pin_memory=False,
        # collate_fn=default_collate
    )
# Out:
# num_imgs: 3226

# %%
for data in val_loader:
    for i in range(len(data['input'])):
        mean=torch.tensor([0.485, 0.456, 0.406]).reshape(1,1,3)
        std=torch.tensor([0.229, 0.224, 0.225]).reshape(1,1,3)
        img=data['input'][i].permute(1,2,0)
        plt.imshow(img*std+mean)
        plt.show()
        print(data['wh'][])
        hm=data['hm'][i]
        plt.imshow(hm[0,...])
        plt.show()

        plt.imshow(hm[1,...])
        plt.show()

        plt.imshow(hm[2,...])
        plt.show()
        input('s')
# Out:
# s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/envs/pytorch/lib/python3.6/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# ~/anaconda3/envs/pytorch/lib/python3.6/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# ~/anaconda3/envs/pytorch/lib/python3.6/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     469         """
# --> 470         parts = [self.recv(flags, copy=copy, track=track)]
#     471         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# ~/anaconda3/envs/pytorch/lib/python3.6/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-5f3f5b31617d> in <module>
#      15         plt.imshow(hm[2,...])
#      16         plt.show()
# ---> 17         input('s')
#
# ~/anaconda3/envs/pytorch/lib/python3.6/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     702             self._parent_ident,
#     703             self._parent_header,
# --> 704             password=False,
#     705         )
#     706
#
# ~/anaconda3/envs/pytorch/lib/python3.6/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     732             except KeyboardInterrupt:
#     733                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 734                 raise KeyboardInterrupt
#     735             else:
#     736                 break
#
# KeyboardInterrupt:

# %%
while True:
    d=next(data)
    for i in range(8):
        mean=torch.tensor([0.485, 0.456, 0.406]).reshape(1,1,3)
        std=torch.tensor([0.229, 0.224, 0.225]).reshape(1,1,3)
        img=d['input'][i].permute(1,2,0)
        plt.imshow(img*std+mean)
        plt.show()
        hm=d['hm'][i]
        plt.imshow(hm[0,...])
        plt.show()

        plt.imshow(hm[1,...])
        plt.show()

        plt.imshow(hm[2,...])
        plt.show()
    input('s')
